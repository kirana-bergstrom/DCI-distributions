# %%
import numpy as np
import matplotlib.pyplot as plt

from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

from scipy.stats import gaussian_kde as GKDE

from scipy.stats import multivariate_normal
from scipy.stats import norm

import weightedCDFs as wCDFs

import weights

import random

import matplotlib.patches as patches

import seaborn as sns
import matplotlib.colors as colors

import matplotlib as mpl

# %%
mpl.rcParams['lines.linewidth'] = 4
plt.rc('font', size=14)
plt.rc('axes', titlesize=16)
plt.rc('axes', labelsize=16)
mpl.rcParams['lines.markersize'] = 5
mpl.rcParams['figure.figsize'] = (5.5, 4)
mpl.rcParams['lines.linewidth'] = 2.5


CB_color_cycle = ('#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00')
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=CB_color_cycle)

# %%
rerun_densities = False
rerun_distributions = False

# %% [markdown]
# ## Problem setup

# %%
random.seed(10)

# %%
l = 2.
kappa = 1.

# %%
N = 100  # Specify the truncation
ts = [1e-4, 1e-2, 1e-1, 0.4, 0.8]
x = np.linspace(0, l, 2*N)

# %%
def u_k(k, x, t, l, kappa):
    
    return (2 * l**2 * (-1)**(k+1) / (np.pi * k)
            * np.sin(k * np.pi * x / l)
            * np.exp(-kappa * (k * np.pi)**2 * t) / l**2)

def u(N, x, t, l, kappa):
    
    u_N = 0 * x
    for k in range(1, N):
        u_N += u_k(k, x, t, l, kappa)

    return u_N

# %%
t = .01
sensor_loc = 1.2

# %%
def rejection_sampling(r):
    
    unifs = np.random.uniform(0,1,len(r))
    M = np.max(r)
    
    return (unifs < (r / M))

# %%
def histogram_dci(init_samples, pred_samples, bbox=None,
                  sample_set_2=None, targ_CDF=None, n_bins=None,
                  remove_empty_bins=True):

    # print(len(pred_samples))
    # print(len(sample_set_2))
    n_samples = len(pred_samples)
    dim_D = np.shape(pred_samples)[1]

    # if n_clusters is not input, then use n_clusters = n_samples / 100
    if n_bins is None: # idk this isn't going to work well in multiple dimensions
        n_bins = (n_samples / 100)
    if isinstance(n_bins, int):
        n_bins = [n_bins] * dim_D
        
    if bbox is not None:
        if dim_D == 1:
            min_pred = bbox[0]
            max_pred = bbox[1]

    else:
        if dim_D == 1:
            min_pred = np.min(pred_samples[:,0])
            max_pred = np.max(pred_samples[:,0])

    # create bins in each dimension
    low_ends = np.empty((np.prod(n_bins), dim_D))
    upp_ends = np.empty((np.prod(n_bins), dim_D))
    if dim_D == 1:
        d_len = (max_pred - min_pred) / n_bins[0]
        low_ends[:,0] = np.linspace(min_pred, max_pred-d_len, n_bins[0])
        upp_ends[:,0] = np.linspace(min_pred+d_len, max_pred, n_bins[0])

    # ok for now this is only going to work in 1 or 2 dimensions because it's fucking recursive again!!!!!!
    # bin samples
    labels = np.empty(n_samples)
    ratios = []
    in_bins_pred = []
    in_bins_obs = []
    n_obs = len(sample_set_2)
    if dim_D == 1:
        counter = 0
        for i in range(n_bins[0]):
            bin_inds = ((pred_samples[:,0] >= low_ends[i,0]) & (pred_samples[:,0] <= upp_ends[i,0]))
            labels[bin_inds] = counter
            ratios.append(np.sum((sample_set_2[:,0] >= low_ends[i,0]) & (sample_set_2[:,0] <= upp_ends[i,0]))/n_obs)
            in_bins_pred.append((np.sum(((pred_samples[:,0] >= low_ends[i,0]) & (pred_samples[:,0] <= upp_ends[i,0])))))
            in_bins_obs.append((np.sum(((sample_set_2[:,0] >= low_ends[i,0]) & (sample_set_2[:,0] <= upp_ends[i,0])))))
            counter += 1

    ratios = np.array(ratios)
    in_bins_pred = np.array(in_bins_pred)
    in_bins_obs = np.array(in_bins_obs)
    w = weights.distributeWeights(init_samples, labels, ratios)
    len_bin = upp_ends[0,0] - low_ends[0,0]
    return w, ratios, labels, in_bins_pred, in_bins_obs, len_bin

# %% [markdown]
# ## Convergence analysis

# %%
low_x = 2.01
upp_x = 2.02
low_y = 0.95
upp_y = 1.0

upp_B = u(N, sensor_loc, t, low_x, low_y)
low_B = u(N, sensor_loc, t, upp_x, upp_y)

delta_l = 0.1
delta_kappa = 0.5

print(f'Upper of B = {upp_B}')
print(f'Lower of B = {low_B}')
# Out:
# Upper of B = 0.5935544013268559
# Lower of B = 0.5899603114552461

# %%
X = np.linspace(l - delta_l / 2, delta_l + l - delta_l / 2, 100)
Y = np.linspace(kappa - delta_kappa / 2, delta_kappa + kappa - delta_kappa / 2, 100)

XX, YY = np.meshgrid(X, Y)
ZZ = np.zeros(np.shape(XX))

for count, x in enumerate(X):
    ZZ[count,:] = u(N, sensor_loc, t, XX[count,:], YY[count,:])

# %%
obs_dist = norm(0.595, 3e-3)

n_obs_samples = 10000
obs_samples = obs_dist.rvs(n_obs_samples)

d_min = np.min(ZZ)
d_max = np.max(ZZ)

print(d_min)
print(d_max)

obs_KDE = GKDE(obs_samples)
# Out:
# 0.5766339652753646
# 0.6136972780535532

# %%
n_init_samples = 50000
n_density_trials = 100

# %%
if rerun_densities:

    true_up_prob_set = []
    for trial in range(n_density_trials):

        print(f'working on trial {trial}')

        init_samples = np.random.uniform(0, 1, (n_init_samples,2))
        init_samples[:,0] = init_samples[:,0] * delta_l + l - delta_l / 2
        init_samples[:,1] = init_samples[:,1] * delta_kappa + kappa - delta_kappa / 2

        pred_samples = np.zeros((n_init_samples, 1))
        pred_samples[:, 0] = u(N, sensor_loc, t, init_samples[:,0], init_samples[:,1])
        pred_KDE = GKDE(pred_samples[:,0])

        r = obs_dist.pdf(pred_samples[:,0]) / pred_KDE(pred_samples.T)
        rn_w = r / n_init_samples

        true_up_prob_set.append(0)
        for i, isamp in enumerate(init_samples):
            if isamp[0] >= low_x and isamp[0] <= upp_x and isamp[1] >= low_y and isamp[1] <= upp_y:
                true_up_prob_set[int(trial)] += rn_w[i]
                
    np.save('./data/convergence_dens_prob_A.npy', np.array(true_up_prob_set))

else:

    init_samples = np.random.uniform(0, 1, (n_init_samples,2))
    init_samples[:,0] = init_samples[:,0] * delta_l + l - delta_l / 2
    init_samples[:,1] = init_samples[:,1] * delta_kappa + kappa - delta_kappa / 2

    pred_samples = np.zeros((n_init_samples, 1))
    pred_samples[:, 0] = u(N, sensor_loc, t, init_samples[:,0], init_samples[:,1])
    pred_KDE = GKDE(pred_samples[:,0])

    r = obs_dist.pdf(pred_samples) / pred_KDE(pred_samples.T)
    rn_w = r / n_init_samples

    true_up_prob_set = np.load('./data/convergence_dens_prob_A.npy')

obs_prob_set = obs_dist.cdf(upp_B) - obs_dist.cdf(low_B)

print(np.std(true_up_prob_set))

true_up_prob_set = np.mean(true_up_prob_set)

# %%
ax = plt.gca()

plt.scatter(init_samples[:,0], init_samples[:,1], c=r/n_init_samples)

plt.contour(XX, YY, ZZ, levels=[low_B, upp_B], colors=['w', 'w']);

set_A = patches.Rectangle((low_x, low_y), upp_x-low_x, upp_y-low_y, color='k',
                          fill=None, zorder=10, linewidth=2.5)
ax.add_patch(set_A)

plt.text(upp_x-0.002, low_y-0.04, r'$A$', fontsize=16)
plt.text(upp_x-0.006, upp_y+0.1, r'$Q^{-1}(B)$', fontsize=16, color='w')

plt.xlabel(r'$\ell$')
plt.ylabel(r'$\kappa$')
plt.xticks(ticks=np.linspace(np.min(XX), np.max(XX), 7),
           labels=["{:.3f}".format(x) for x in np.linspace(np.min(XX), np.max(XX), 7)])

plt.tight_layout()
# plt.savefig('/Users/kirana/Desktop/work/paper/sets_Lambda.png', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4486, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4485 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4486     colors = mcolors.to_rgba_array(c)
#    4487 except (TypeError, ValueError) as err:
#
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/colors.py:505, in to_rgba_array(c, alpha)
#     504 else:
# --> 505     rgba = np.array([to_rgba(cc) for cc in c])
#     507 if alpha is not None:
#
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/colors.py:302, in to_rgba(c, alpha)
#     301 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 302     rgba = _to_rgba_no_colorcycle(c, alpha)
#     303     try:
#
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/colors.py:393, in _to_rgba_no_colorcycle(c, alpha)
#     392 if len(c) not in [3, 4]:
# --> 393     raise ValueError("RGBA sequence should have length 3 or 4")
#     394 if not all(isinstance(x, Real) for x in c):
#     395     # Checks that don't work: `map(float, ...)`, `np.array(..., float)` and
#     396     # `np.array(...).astype(float)` would all convert "0.5" to 0.5.
#
# ValueError: RGBA sequence should have length 3 or 4
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 3
#       1 ax = plt.gca()
# ----> 3 plt.scatter(init_samples[:,0], init_samples[:,1], c=r/n_init_samples)
#       5 plt.contour(XX, YY, ZZ, levels=[low_B, upp_B], colors=['w', 'w']);
#       7 set_A = patches.Rectangle((low_x, low_y), upp_x-low_x, upp_y-low_y, color='k',
#       8                           fill=None, zorder=10, linewidth=2.5)
#
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/pyplot.py:3699, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3680 @_copy_docstring_and_deprecators(Axes.scatter)
#    3681 def scatter(
#    3682     x: float | ArrayLike,
#    (...)
#    3697     **kwargs,
#    3698 ) -> PathCollection:
# -> 3699     __ret = gca().scatter(
#    3700         x,
#    3701         y,
#    3702         s=s,
#    3703         c=c,
#    3704         marker=marker,
#    3705         cmap=cmap,
#    3706         norm=norm,
#    3707         vmin=vmin,
#    3708         vmax=vmax,
#    3709         alpha=alpha,
#    3710         linewidths=linewidths,
#    3711         edgecolors=edgecolors,
#    3712         plotnonfinite=plotnonfinite,
#    3713         **({"data": data} if data is not None else {}),
#    3714         **kwargs,
#    3715     )
#    3716     sci(__ret)
#    3717     return __ret
#
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4673, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4670 if edgecolors is None:
#    4671     orig_edgecolor = kwargs.get('edgecolor', None)
#    4672 c, colors, edgecolors = \
# -> 4673     self._parse_scatter_color_args(
#    4674         c, edgecolors, kwargs, x.size,
#    4675         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4677 if plotnonfinite and colors is None:
#    4678     c = np.ma.masked_invalid(c)
#
# File ~/miniforge3/envs/dci/lib/python3.12/site-packages/matplotlib/axes/_axes.py:4492, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4490 else:
#    4491     if not valid_shape:
# -> 4492         raise invalid_shape_exception(c.size, xsize) from err
#    4493     # Both the mapping *and* the RGBA conversion failed: pretty
#    4494     # severe failure => one may appreciate a verbose feedback.
#    4495     raise ValueError(
#    4496         f"'c' argument must be a color, a sequence of colors, "
#    4497         f"or a sequence of numbers, not {c!r}") from err
#
# ValueError: 'c' argument has 25000000 elements, which is inconsistent with 'x' and 'y' with size 5000.

# %%
xx = np.linspace(np.min(pred_samples[:,0]), np.max(pred_samples[:,0]), 1000)
plt.plot(xx, obs_KDE(xx), label=r'$\pi_{obs}$', color='k')
plt.yticks(fontsize=14)
plt.text((upp_B-low_B)/2 + low_B, 145, r'$B$', color='r', fontsize=16,
         horizontalalignment='center', verticalalignment='center')
plt.text(low_B, 145, r'$[$', color='r', fontsize=16, horizontalalignment='center', verticalalignment='center')
plt.text(upp_B, 145, r'$]$', color='r', fontsize=16, horizontalalignment='center', verticalalignment='center')
plt.axvspan(low_B, upp_B, alpha=0.3, color='r')

plt.legend(loc='upper right', shadow=True)
plt.xlabel(r'$u$')
plt.xticks(ticks=np.linspace(np.min(xx), np.max(xx), 7),
           labels=["{:.3f}".format(x) for x in np.linspace(np.min(xx), np.max(xx), 7)], color='k')

plt.tight_layout()
# plt.savefig('/Users/kirana/Desktop/work/paper/sets_D.png', bbox_inches='tight')

# %%
bin_numbers = [16, 32, 64, 128, 256, 512, 1024, 2048]
bin_numbers = [50, 100, 150, 200, 350, 400, 450, 500]
bin_numbers = [20,  40,   60, 80,  100,  120,  140, 160]
bin_numbers = [20,  40,   60, 80,  100,  120,  140, 160]
# bin_numbers = [10,  20, 30, 40, 50, 60, 70, 80]
# bin_numbers = [10, 15, 20, 25, 30, 35, 40]
# init_samples_numbers = [5000, 10000, 15000, 20000, 25000, 35000, 40000, 45000, 50000]
init_samples_numbers = [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000]
# init_samples_numbers = [500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500, 5000]
# init_samples_numbers = [2000, 4000, 6000, 8000, 10000, 12000, 14000, 16000, 18000, 20000]

# %%
f, axs = plt.subplots(3, 3, sharey=True, sharex=True, figsize=(12,6))

for i in range(3):
    for j in range(3):
        
        n_init_samples = init_samples_numbers[i * 3 + j]

        set_A = patches.Rectangle((low_x, low_y), upp_x-low_x, upp_y-low_y, color='r', fill=None, linewidth=3)
        axs[i,j].add_patch(set_A)
        axs[i,j].scatter(init_samples[:n_init_samples,0], init_samples[:n_init_samples,1], s=2)
        axs[i,j].set_title(f'Total samples = {n_init_samples}, in A = {count_A[i * 3 + j]}', fontsize=12)

# plt.savefig('/Users/kirana/Desktop/work/paper/init_samples_convergence.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[129], line 11
#       9         axs[i,j].add_patch(set_A)
#      10         axs[i,j].scatter(init_samples[:n_init_samples,0], init_samples[:n_init_samples,1], s=2)
# ---> 11         axs[i,j].set_title(f'Total samples = {n_init_samples}, in A = {count_A[i * 3 + j]}', fontsize=12)
#      13 # plt.savefig('/Users/kirana/Desktop/work/paper/init_samples_convergence.png')
#
# NameError: name 'count_A' is not defined

# %%
print(true_up_prob_set)
print(ccc_A[0,0]-true_up_prob_set)
print(ccc_A[-1,-1] - true_up_prob_set)

# %%
n_trials = 500

# %%
if rerun_distributions == True:

    c_A = []
    c_B = []

    for trial in range(n_trials):
        
        print(f'working on trial {trial}')

        comp_prob_A = []
        comp_prob_B = []

        init_samples_full = np.random.uniform(0, 1, (init_samples_numbers[-1], 2))
        init_samples_full[:,0] = init_samples_full[:,0] * delta_l + l - delta_l / 2
        init_samples_full[:,1] = init_samples_full[:,1] * delta_kappa + kappa - delta_kappa / 2

        pred_samples_full = np.zeros((init_samples_numbers[-1], 1))
        pred_samples_full[:, 0] = u(N, sensor_loc, t, init_samples_full[:,0], init_samples_full[:,1])

        for i, n_init_samples in enumerate(init_samples_numbers):

            comp_prob_A.append([])
            comp_prob_B.append([])

            init_samples = init_samples_full[:n_init_samples,:]

            pred_samples = pred_samples_full[:n_init_samples,:]
            pred_KDE = GKDE(pred_samples[:,0])

            for b, n_bins in enumerate(bin_numbers):
                w, bins, centers, w_center = weights.computePartitionedWeights_regulargrid_IID(init_samples,
                                                                        pred_samples,
                                                                        targ_CDF=obs_dist.cdf,
                                                                        # sample_set_2=np.reshape(obs_samples, (len(obs_samples),1)),
                                                                        n_bins=n_bins)

                weight_set = 0
                for count, psamp in enumerate(pred_samples): 
                    if psamp >= low_B and psamp <= upp_B:
                        weight_set += w[count]

                up_prob_set = 0
                for count, isamp in enumerate(init_samples):
                    if isamp[0] >= low_x and isamp[0] <= upp_x and isamp[1] >= low_y and isamp[1] <= upp_y:
                        up_prob_set += w[count]

                comp_prob_B[i].append(weight_set)
                comp_prob_A[i].append(up_prob_set)

        c_A.append(comp_prob_A)
        c_B.append(comp_prob_B)

    dist_prob_A = np.array(c_A)
    dist_prob_B = np.array(c_B)

    np.save('./data/convergence_qp_prob_A.npy', dist_prob_A.reshape(n_trials, -1))
    np.save('./data/convergence_qp_prob_B.npy', dist_prob_B.reshape(n_trials, -1))
    
else:

    dist_prob_A = np.load('./data/convergence_qp_prob_A.npy').reshape(n_trials,
                                                                        len(init_samples_numbers),
                                                                        len(bin_numbers))
    dist_prob_B = np.load('./data/convergence_qp_prob_B.npy').reshape(n_trials,
                                                                        len(init_samples_numbers),
                                                                        len(bin_numbers))
# Out:
# working on trial 0
# working on trial 1
# working on trial 2
# working on trial 3
# working on trial 4
# working on trial 5
# working on trial 6
# working on trial 7
# working on trial 8
# working on trial 9
# working on trial 10
# working on trial 11
# working on trial 12
# working on trial 13
# working on trial 14
# working on trial 15
# working on trial 16
# working on trial 17
# working on trial 18
# working on trial 19
# working on trial 20
# working on trial 21
# working on trial 22
# working on trial 23
# working on trial 24
# working on trial 25
# working on trial 26
# working on trial 27
# working on trial 28
# working on trial 29
# working on trial 30
# working on trial 31
# working on trial 32
# working on trial 33
# working on trial 34
# working on trial 35
# working on trial 36
# working on trial 37
# working on trial 38
# working on trial 39
# working on trial 40
# working on trial 41
# working on trial 42
# working on trial 43
# working on trial 44
# working on trial 45
# working on trial 46
# working on trial 47
# working on trial 48
# working on trial 49
# working on trial 50
# working on trial 51
# working on trial 52
# working on trial 53
# working on trial 54
# working on trial 55
# working on trial 56
# working on trial 57
# working on trial 58
# working on trial 59
# working on trial 60
# working on trial 61
# working on trial 62
# working on trial 63
# working on trial 64
# working on trial 65
# working on trial 66
# working on trial 67
# working on trial 68
# working on trial 69
# working on trial 70
# working on trial 71
# working on trial 72
# working on trial 73
# working on trial 74
# working on trial 75
# working on trial 76
# working on trial 77
# working on trial 78
# working on trial 79
# working on trial 80
# working on trial 81
# working on trial 82
# working on trial 83
# working on trial 84
# working on trial 85
# working on trial 86
# working on trial 87
# working on trial 88
# working on trial 89
# working on trial 90
# working on trial 91
# working on trial 92
# working on trial 93
# working on trial 94
# working on trial 95
# working on trial 96
# working on trial 97
# working on trial 98
# working on trial 99
# working on trial 100
# working on trial 101
# working on trial 102
# working on trial 103
# working on trial 104
# working on trial 105
# working on trial 106
# working on trial 107
# working on trial 108
# working on trial 109
# working on trial 110
# working on trial 111
# working on trial 112
# working on trial 113
# working on trial 114
# working on trial 115
# working on trial 116
# working on trial 117
# working on trial 118
# working on trial 119
# working on trial 120
# working on trial 121
# working on trial 122
# working on trial 123
# working on trial 124
# working on trial 125
# working on trial 126
# working on trial 127
# working on trial 128
# working on trial 129
# working on trial 130
# working on trial 131
# working on trial 132
# working on trial 133
# working on trial 134
# working on trial 135
# working on trial 136
# working on trial 137
# working on trial 138
# working on trial 139
# working on trial 140
# working on trial 141
# working on trial 142
# working on trial 143
# working on trial 144
# working on trial 145
# working on trial 146
# working on trial 147
# working on trial 148
# working on trial 149
# working on trial 150
# working on trial 151
# working on trial 152
# working on trial 153
# working on trial 154
# working on trial 155
# working on trial 156
# working on trial 157
# working on trial 158
# working on trial 159
# working on trial 160
# working on trial 161
# working on trial 162
# working on trial 163
# working on trial 164
# working on trial 165
# working on trial 166
# working on trial 167
# working on trial 168
# working on trial 169
# working on trial 170
# working on trial 171
# working on trial 172
# working on trial 173
# working on trial 174
# working on trial 175
# working on trial 176
# working on trial 177
# working on trial 178
# working on trial 179
# working on trial 180
# working on trial 181
# working on trial 182
# working on trial 183
# working on trial 184
# working on trial 185
# working on trial 186
# working on trial 187
# working on trial 188
# working on trial 189
# working on trial 190
# working on trial 191
# working on trial 192
# working on trial 193
# working on trial 194
# working on trial 195
# working on trial 196
# working on trial 197
# working on trial 198
# working on trial 199
# working on trial 200
# working on trial 201
# working on trial 202
# working on trial 203
# working on trial 204
# working on trial 205
# working on trial 206
# working on trial 207
# working on trial 208
# working on trial 209
# working on trial 210
# working on trial 211
# working on trial 212
# working on trial 213
# working on trial 214
# working on trial 215
# working on trial 216
# working on trial 217
# working on trial 218
# working on trial 219
# working on trial 220
# working on trial 221
# working on trial 222
# working on trial 223
# working on trial 224
# working on trial 225
# working on trial 226
# working on trial 227
# working on trial 228
# working on trial 229
# working on trial 230
# working on trial 231
# working on trial 232
# working on trial 233
# working on trial 234
# working on trial 235
# working on trial 236
# working on trial 237
# working on trial 238
# working on trial 239
# working on trial 240
# working on trial 241
# working on trial 242
# working on trial 243
# working on trial 244
# working on trial 245
# working on trial 246
# working on trial 247
# working on trial 248
# working on trial 249
# working on trial 250
# working on trial 251
# working on trial 252
# working on trial 253
# working on trial 254
# working on trial 255
# working on trial 256
# working on trial 257
# working on trial 258
# working on trial 259
# working on trial 260
# working on trial 261
# working on trial 262
# working on trial 263
# working on trial 264
# working on trial 265
# working on trial 266
# working on trial 267
# working on trial 268
# working on trial 269
# working on trial 270
# working on trial 271
# working on trial 272
# working on trial 273
# working on trial 274
# working on trial 275
# working on trial 276
# working on trial 277
# working on trial 278
# working on trial 279
# working on trial 280
# working on trial 281
# working on trial 282
# working on trial 283
# working on trial 284
# working on trial 285
# working on trial 286
# working on trial 287
# working on trial 288
# working on trial 289
# working on trial 290
# working on trial 291
# working on trial 292
# working on trial 293
# working on trial 294
# working on trial 295
# working on trial 296
# working on trial 297
# working on trial 298
# working on trial 299
# working on trial 300
# working on trial 301
# working on trial 302
# working on trial 303
# working on trial 304
# working on trial 305
# working on trial 306
# working on trial 307
# working on trial 308
# working on trial 309
# working on trial 310
# working on trial 311
# working on trial 312
# working on trial 313
# working on trial 314
# working on trial 315
# working on trial 316
# working on trial 317
# working on trial 318
# working on trial 319
# working on trial 320
# working on trial 321
# working on trial 322
# working on trial 323
# working on trial 324
# working on trial 325
# working on trial 326
# working on trial 327
# working on trial 328
# working on trial 329
# working on trial 330
# working on trial 331
# working on trial 332
# working on trial 333
# working on trial 334
# working on trial 335
# working on trial 336
# working on trial 337
# working on trial 338
# working on trial 339
# working on trial 340
# working on trial 341
# working on trial 342
# working on trial 343
# working on trial 344
# working on trial 345
# working on trial 346
# working on trial 347
# working on trial 348
# working on trial 349
# working on trial 350
# working on trial 351
# working on trial 352
# working on trial 353
# working on trial 354
# working on trial 355
# working on trial 356
# working on trial 357
# working on trial 358
# working on trial 359
# working on trial 360
# working on trial 361
# working on trial 362
# working on trial 363
# working on trial 364
# working on trial 365
# working on trial 366
# working on trial 367
# working on trial 368
# working on trial 369
# working on trial 370
# working on trial 371
# working on trial 372
# working on trial 373
# working on trial 374
# working on trial 375
# working on trial 376
# working on trial 377
# working on trial 378
# working on trial 379
# working on trial 380
# working on trial 381
# working on trial 382
# working on trial 383
# working on trial 384
# working on trial 385
# working on trial 386
# working on trial 387
# working on trial 388
# working on trial 389
# working on trial 390
# working on trial 391
# working on trial 392
# working on trial 393
# working on trial 394
# working on trial 395
# working on trial 396
# working on trial 397
# working on trial 398
# working on trial 399
# working on trial 400
# working on trial 401
# working on trial 402
# working on trial 403
# working on trial 404
# working on trial 405
# working on trial 406
# working on trial 407
# working on trial 408
# working on trial 409
# working on trial 410
# working on trial 411
# working on trial 412
# working on trial 413
# working on trial 414
# working on trial 415
# working on trial 416
# working on trial 417
# working on trial 418
# working on trial 419
# working on trial 420
# working on trial 421
# working on trial 422
# working on trial 423
# working on trial 424
# working on trial 425
# working on trial 426
# working on trial 427
# working on trial 428
# working on trial 429
# working on trial 430
# working on trial 431
# working on trial 432
# working on trial 433
# working on trial 434
# working on trial 435
# working on trial 436
# working on trial 437
# working on trial 438
# working on trial 439
# working on trial 440
# working on trial 441
# working on trial 442
# working on trial 443
# working on trial 444
# working on trial 445
# working on trial 446
# working on trial 447
# working on trial 448
# working on trial 449
# working on trial 450
# working on trial 451
# working on trial 452
# working on trial 453
# working on trial 454
# working on trial 455
# working on trial 456
# working on trial 457
# working on trial 458
# working on trial 459
# working on trial 460
# working on trial 461
# working on trial 462
# working on trial 463
# working on trial 464
# working on trial 465
# working on trial 466
# working on trial 467
# working on trial 468
# working on trial 469
# working on trial 470
# working on trial 471
# working on trial 472
# working on trial 473
# working on trial 474
# working on trial 475
# working on trial 476
# working on trial 477
# working on trial 478
# working on trial 479
# working on trial 480
# working on trial 481
# working on trial 482
# working on trial 483
# working on trial 484
# working on trial 485
# working on trial 486
# working on trial 487
# working on trial 488
# working on trial 489
# working on trial 490
# working on trial 491
# working on trial 492
# working on trial 493
# working on trial 494
# working on trial 495
# working on trial 496
# working on trial 497
# working on trial 498
# working on trial 499

# %%
ccc_A = np.mean(dist_prob_A, axis=0)
ccc_B = np.mean(dist_prob_B, axis=0)

# %%
plt.figure(figsize=(12,4.8))

# s = sns.heatmap(np.abs(np.array(ccc_B)-obs_prob_set), annot=True, cmap='viridis', fmt='0.2E',
#             yticklabels=init_samples_numbers, xticklabels=bin_numbers,
#             norm=colors.LogNorm(vmin=np.min(np.abs(np.array(ccc_B)-obs_prob_set)),
#                                 vmax=np.max(np.abs(np.array(ccc_B)-obs_prob_set))));
s = sns.heatmap(np.abs(np.array(ccc_B)-obs_prob_set), annot=True, cmap='viridis', fmt='0.2E',
            yticklabels=init_samples_numbers, xticklabels=bin_numbers);

s.set_xlabel('$p$')
s.set_ylabel('$n$')

plt.tight_layout()
plt.savefig(f'/Users/kirana/Desktop/work/thesis/figures/heatmap_meanB.png', bbox_inches='tight')

# %%
frow_string = f'        '
for i in bin_numbers:
    frow_string += f' {i:6d}  '

print(frow_string)
for ii, b in enumerate(ccc_B):
    row_string = f'{init_samples_numbers[ii]:5d}   '
    for i in b:
        if i != -999:
            row_string += f'{i:.5f}  '
        else:
            row_string += f'         '
    print(row_string)

print()
print(f'actual probability of B = {obs_prob_set:.5f}')
# Out:
#              20       40       60       80      100      120      140      160
#  1000   0.26769  0.26814  0.26824  0.26839  0.26841  0.26868  0.26865  0.26850
#  2000   0.26721  0.26798  0.26827  0.26843  0.26846  0.26841  0.26847  0.26848
#  3000   0.26696  0.26803  0.26831  0.26841  0.26845  0.26849  0.26843  0.26844
#  4000   0.26672  0.26802  0.26833  0.26843  0.26860  0.26858  0.26852  0.26847
#  5000   0.26652  0.26791  0.26825  0.26834  0.26852  0.26847  0.26850  0.26839
#  6000   0.26648  0.26790  0.26824  0.26830  0.26845  0.26845  0.26849  0.26838
#  7000   0.26650  0.26796  0.26830  0.26837  0.26849  0.26848  0.26853  0.26841
#  8000   0.26638  0.26795  0.26831  0.26841  0.26849  0.26845  0.26847  0.26838
#  9000   0.26630  0.26793  0.26831  0.26842  0.26846  0.26851  0.26849  0.26841
# 10000   0.26632  0.26797  0.26835  0.26844  0.26852  0.26854  0.26848  0.26839
#
# actual probability of B = 0.26846

# %%
plt.figure(figsize=(12,4.8))

# s = sns.heatmap(np.abs(np.array(ccc_A)-true_up_prob_set), annot=True, cmap='viridis', fmt='0.2E',
#                 yticklabels=init_samples_numbers, xticklabels=bin_numbers,
#                 norm=colors.LogNorm(vmin=np.min(np.abs(np.array(ccc_A)-true_up_prob_set)),
#                                     vmax=np.max(np.abs(np.array(ccc_A)-true_up_prob_set))));
s = sns.heatmap(np.abs(np.array(ccc_A)-true_up_prob_set)/true_up_prob_set, annot=True, cmap='viridis', fmt='0.2E',
                yticklabels=init_samples_numbers, xticklabels=bin_numbers);


s.set_xlabel('$p$')
s.set_ylabel('$n$')

plt.tight_layout()
plt.savefig(f'/Users/kirana/Desktop/work/thesis/figures/heatmap_meanA.png', bbox_inches='tight')

# %%
true_up_prob_set = 0.01965
frow_string = f'        '
for i in bin_numbers:
    frow_string += f' {i:6d}  '

print(frow_string)
for ii, b in enumerate(ccc_A):
    row_string = f'{init_samples_numbers[ii]:5d}   '
    for i in b:
        if i != -999:
            row_string += f'{i:.5f}  '
        else:
            row_string += f'         '
    print(row_string)

print()
print(f'actual probability of A = {true_up_prob_set:.5f}')
# Out:
#              20       40       60       80      100      120      140      160
#  1000   0.01989  0.02000  0.01992  0.01996  0.01985  0.01981  0.01988  0.01986
#  2000   0.01974  0.01990  0.01991  0.01985  0.01988  0.01989  0.01986  0.01984
#  3000   0.01948  0.01969  0.01969  0.01966  0.01965  0.01968  0.01962  0.01963
#  4000   0.01954  0.01976  0.01977  0.01974  0.01975  0.01976  0.01973  0.01972
#  5000   0.01936  0.01961  0.01961  0.01960  0.01959  0.01960  0.01960  0.01959
#  6000   0.01940  0.01964  0.01963  0.01962  0.01963  0.01961  0.01961  0.01962
#  7000   0.01939  0.01964  0.01963  0.01962  0.01963  0.01963  0.01962  0.01962
#  8000   0.01938  0.01964  0.01963  0.01962  0.01962  0.01962  0.01961  0.01962
#  9000   0.01940  0.01966  0.01965  0.01964  0.01965  0.01964  0.01963  0.01965
# 10000   0.01940  0.01967  0.01964  0.01965  0.01965  0.01965  0.01964  0.01964
#
# actual probability of A = 0.01965

# %%
cccc_A = np.std(dist_prob_A, axis=0)
cccc_B = np.std(dist_prob_B, axis=0)

# %%
plt.figure(figsize=(12,4.8))

s = sns.heatmap(np.abs(np.array(cccc_B)), annot=True, cmap='viridis', fmt='0.2E',
                yticklabels=init_samples_numbers, xticklabels=bin_numbers);

s.set_xlabel('$p$')
s.set_ylabel('$n$')

plt.tight_layout()
plt.savefig(f'/Users/kirana/Desktop/work/thesis/figures/heatmap_stdB.png', bbox_inches='tight')

# %%
plt.figure(figsize=(12,4.8))

s = sns.heatmap(np.abs(np.array(cccc_A)), annot=True, cmap='viridis', fmt='0.2E',
                yticklabels=init_samples_numbers, xticklabels=bin_numbers);
s.set_xlabel('$p$')
s.set_ylabel('$n$')

plt.tight_layout()
plt.savefig(f'/Users/kirana/Desktop/work/thesis/figures/heatmap_stdA.png', bbox_inches='tight')
